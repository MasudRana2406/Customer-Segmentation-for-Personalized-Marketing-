# %% [markdown]
# <a href="https://colab.research.google.com/github/MasudRana2406/Customer-Segmentation-for-Personalized-Marketing-/blob/main/Demand_Forecasting_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
datasets_list = os.listdir('/content/drive/MyDrive/2nd Year/Semester A/m5-forecasting-accuracy')

for files in datasets_list:
    print(files)
# Out:
# sell_prices.csv
# calendar.csv
# sales_train_evaluation.csv
# sales_train_validation.csv
# sample_submission.csv

# %%
sales_train_evaluation = pd.read_csv('/content/drive/MyDrive/2nd Year/Semester A/m5-forecasting-accuracy/sales_train_evaluation.csv')
sales_train_evaluation.head(2)
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_evaluation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_evaluation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
#
#   state_id  d_1  d_2  d_3  d_4  ...  d_1932  d_1933  d_1934  d_1935  d_1936  \
# 0       CA    0    0    0    0  ...       2       4       0       0       0
# 1       CA    0    0    0    0  ...       0       1       2       1       1
#
#    d_1937  d_1938  d_1939  d_1940  d_1941
# 0       0       3       3       0       1
# 1       0       0       0       0       0
#
# [2 rows x 1947 columns]

# %%
sales_train_evaluation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30490 entries, 0 to 30489
# Columns: 1947 entries, id to d_1941
# dtypes: int64(1941), object(6)
# memory usage: 452.9+ MB

# %%
calendar = pd.read_csv('/content/drive/MyDrive/2nd Year/Semester A/m5-forecasting-accuracy/calendar.csv')
calendar.head(2)
# Out:
#          date  wm_yr_wk   weekday  wday  month  year    d event_name_1  \
# 0  2011-01-29     11101  Saturday     1      1  2011  d_1          NaN
# 1  2011-01-30     11101    Sunday     2      1  2011  d_2          NaN
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 0          NaN          NaN          NaN        0        0        0
# 1          NaN          NaN          NaN        0        0        0

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1969 entries, 0 to 1968
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1969 non-null   object
#  1   wm_yr_wk      1969 non-null   int64
#  2   weekday       1969 non-null   object
#  3   wday          1969 non-null   int64
#  4   month         1969 non-null   int64
#  5   year          1969 non-null   int64
#  6   d             1969 non-null   object
#  7   event_name_1  162 non-null    object
#  8   event_type_1  162 non-null    object
#  9   event_name_2  5 non-null      object
#  10  event_type_2  5 non-null      object
#  11  snap_CA       1969 non-null   int64
#  12  snap_TX       1969 non-null   int64
#  13  snap_WI       1969 non-null   int64
# dtypes: int64(7), object(7)
# memory usage: 215.5+ KB

# %%
sales = pd.read_csv('/content/drive/MyDrive/2nd Year/Semester A/m5-forecasting-accuracy/sales_train_validation.csv')
sales.head(2)
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
#
#   state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  d_1906  d_1907  d_1908  \
# 0       CA    0    0    0    0  ...       1       3       0       1       1
# 1       CA    0    0    0    0  ...       0       0       0       0       0
#
#    d_1909  d_1910  d_1911  d_1912  d_1913
# 0       1       3       0       1       1
# 1       1       0       0       0       0
#
# [2 rows x 1919 columns]

# %%
sales_train_validation.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3372302864.py in <cell line: 0>()
# ----> 1 sales_train_validation.info()
#
# NameError: name 'sales_train_validation' is not defined

# %%
sample_submission = pd.read_csv('/content/drive/MyDrive/2nd Year/Semester A/m5-forecasting-accuracy/sample_submission.csv')
sample_submission.head(2)

# %%
sample_submission.info()

# %%
prices  = pd.read_csv('/content/drive/MyDrive/2nd Year/Semester A/m5-forecasting-accuracy/sell_prices.csv')
prices .head(2)
# Out:
#   store_id        item_id  wm_yr_wk  sell_price
# 0     CA_1  HOBBIES_1_001     11325        9.58
# 1     CA_1  HOBBIES_1_001     11326        9.58

# %%
prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6841121 entries, 0 to 6841120
# Data columns (total 4 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   store_id    object
#  1   item_id     object
#  2   wm_yr_wk    int64
#  3   sell_price  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 208.8+ MB

# %%
for name, df in {'Calendar': calendar, 'Sales': sales, 'Prices': prices}.items():
    print(f"{name}: {df.shape}")
    print(df.head(2), "\n")
# Out:
# Calendar: (1969, 14)
#          date  wm_yr_wk   weekday  wday  month  year    d event_name_1  \
# 0  2011-01-29     11101  Saturday     1      1  2011  d_1          NaN
# 1  2011-01-30     11101    Sunday     2      1  2011  d_2          NaN
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 0          NaN          NaN          NaN        0        0        0
# 1          NaN          NaN          NaN        0        0        0
#
# Sales: (30490, 1919)
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
#
#   state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  d_1906  d_1907  d_1908  \
# 0       CA    0    0    0    0  ...       1       3       0       1       1
# 1       CA    0    0    0    0  ...       0       0       0       0       0
#
# ...

# %%
sales_long = sales.melt(
    id_vars=['id','item_id','dept_id','cat_id','store_id','state_id'],
    var_name='d', value_name='sales'
)

# %%
sales_long = sales_long.merge(calendar[['d','date']], on='d', how='left')
sales_long['date'] = pd.to_datetime(sales_long['date'])

# %%
sales_long = sales_long.merge(
    prices, on=['store_id','item_id'], how='left'
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1977367336.py in <cell line: 0>()
# ----> 1 sales_long = sales_long.merge(
#       2     prices, on=['store_id','item_id'], how='left'
#       3 )
#
# NameError: name 'sales_long' is not defined

# %% [markdown]
# https://www.kaggle.com/code/m26102002/end-to-end-retail-sales-forecasting-walmart   for forcasting

# %% [markdown]
# https://www.kaggle.com/code/vislupus/inventory-optimization
#   to create synthetic data

# %% [markdown]
# Dataset Structure
#
# It’s split across several files:
#
# sales_train_validation.csv
#
# Historical daily unit sales per item/store combo.
#
# Columns: id, item_id, dept_id, cat_id, store_id, state_id, and d_1–d_1913 (days).
#
# calendar.csv
#
# Maps d_1–d_1913 to actual dates.
#
# Includes event names, SNAP (food stamp eligibility), and weekday info.
#
# sell_prices.csv
#
# The selling price of each item per week and store.
#
# sales_train_evaluation.csv
#
# Similar to the training data, but extends a bit further in time for evaluation purposes.
#
# sample_submission.csv
#
# Format for submitting forecasts — columns for the next 28 days (F1–F28) per series.

# %% [markdown]
# Participants must forecast the next 28 days of sales for each item.
# Accuracy is evaluated using Weighted Root Mean Squared Scaled Error (WRMSSE), which penalizes errors more heavily for high-selling products.

# %% [markdown]
# 13/10/2025
#
#
# literature review
#
# * build connection
# * example
# * Select 10 paper , skim & find any common research paper .

# %%
*
